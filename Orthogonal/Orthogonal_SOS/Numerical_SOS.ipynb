# %% [markdown]
# # Numerical SOS decomposition

# %% [markdown]
# ## Preliminaries

# %%
import numpy as np
import matplotlib.pyplot as plt
import ncpol2sdpa as ncp
import json

# Define quantum operators
A_config = [2,2]
B_config = [2,2]

# Operators in problem
A = [Ai for Ai in ncp.generate_measurements(A_config, 'A')]
B = [Bj for Bj in ncp.generate_measurements(B_config, 'B')]

ops = ncp.flatten([A,B])        # Base monomials involved in problem
subs = {}

# 1. Unitarity: A^2 = 1
for op in ops:
    subs[op**2] = 1

# 2. Commutation: force a canonical ordering B*A → A*B
for Ai in ncp.flatten(A):
    for Bj in ncp.flatten(B):
        subs[Bj * Ai] = Ai * Bj

# %% [markdown]
# ## Test: the CHSH expression

# %%
moment_ineqs = []                      # moment inequalities
moment_eqs = []                        # moment equalities
op_eqs = []                            # operator equalities
op_ineqs = []                          # operator inequalities
extra_monos = []                       # extra monomials

obj = (A[0][0]*B[0][0] + A[1][0]*B[0][0] + A[0][0]*B[1][0] - A[1][0]*B[1][0])/(2*np.sqrt(2))

sdp = ncp.SdpRelaxation(ops, verbose=0, normalized=True, parallel=0)
sdp.get_relaxation(
    level=5,
    equalities = op_eqs[:],
    inequalities = op_ineqs[:],
    momentequalities = moment_eqs[:],
    momentinequalities = moment_ineqs[:],
    objective=obj,
    substitutions = subs,
    extramonomials = extra_monos
)
sdp.solve(solver="mosek")
print(-sdp.primal, -sdp.dual, sdp.status)
# Out:
# 1.0000000000810259 0.9999999999441891 optimal

# %% [markdown]
# ## Testing Function

# %%
def test_point_quantum_bound(theta, r0, r1, level=0, verbose=False):
    """
    Tests whether a point (parametrized by theta, r0 = p1, r1 = 2*p4) is quantum-realizable
    by solving the associated SDP relaxation at level 0 with different sets of monomials.

    Parameters:
    -----------
    theta : float
        The measurement angle θ in radians.
    r0 : float
        Parameter such that p1 = r0.
    r1 : float
        Parameter such that p4 = 0.5 * r1.
    level : str or int
        Level of the relaxation: 0, 'AB', 'ABB', or 'AAB'.
    solver : str
        SDP solver to use (e.g., "mosek", "cvxopt", "sdpa").
    verbose : bool
        Whether to print verbose SDP solver output.

    Returns:
    --------
    primal : float
        The negative primal bound.
    dual : float
        The negative dual bound.
    status : str
        The solver status string.
    """

    s = np.sqrt(2)
    sin_2T = np.sin(2 * theta)
    sin_4T = np.sin(4 * theta)
    cos_2T = np.cos(2 * theta)
    cos_4T = np.cos(4 * theta)
    cos_6T = np.cos(6 * theta)

    # Define objective expression
    obj = (-1/(2*(3 - cos_4T))*0.5*r1*(-4*B[1][0]*(-3 + cos_4T) + s*(-5*cos_2T + cos_6T)*A[0][0]*B[1][0] 
        + s*(-5*cos_2T + cos_6T)*A[1][0]*B[1][0] + 2*s*A[0][0]*(-3 + cos_4T)*sin_2T - 2*s*A[1][0]*(-3 + cos_4T)*sin_2T) 
        - 1/(2*(3 - cos_4T))*(-4*B[0][0]*cos_2T - s*A[0][0]*B[0][0] + s*cos_4T*A[0][0]*B[0][0] - s*A[1][0]*B[0][0] 
        + s*cos_4T*A[1][0]*B[0][0] - 2*s*A[0][0]*B[1][0]*sin_2T + 2*s*A[1][0]*B[1][0]*sin_2T) 
        - 1/(2*(3 - cos_4T))*r0*(s*A[0][0]*(-3 + cos_4T) + s*A[1][0]*(-3 + cos_4T) - 4*B[0][0]*(-1 + cos_4T) 
        + 2*s*cos_2T*A[0][0]*B[0][0] + 2*s*cos_2T*A[1][0]*B[0][0] - 2*s*cos_2T*A[0][0]*B[1][0]*sin_2T + s*A[1][0]*B[1][0]*sin_4T))

    def get_extra_monomials(level):
        """
        Generate extra monomials for a given level string such as:
        'AA', 'BB', 'AB', 'AAB', 'ABB', 'AA+BB+AB+AAB+ABB', etc.
        """
        if level in [0, '0', None]:
            return []

        level_parts = level.split('+') if isinstance(level, str) else []
        monos = []
        Aflat = ncp.flatten(A)
        Bflat = ncp.flatten(B)

        if 'AA' in level_parts:
            for a1 in Aflat:
                for a2 in Aflat:
                    monos.append(a1 * a2)

        if 'BB' in level_parts:
            for b1 in Bflat:
                for b2 in Bflat:
                    monos.append(b1 * b2)

        if 'AB' in level_parts:
            for a in Aflat:
                for b in Bflat:
                    monos.append(a * b)

        if 'AAB' in level_parts:
            for a1 in Aflat:
                for a2 in Aflat:
                    for b in Bflat:
                        monos.append(a1 * a2 * b)

        if 'ABB' in level_parts:
            for a in Aflat:
                for b1 in Bflat:
                    for b2 in Bflat:
                        monos.append(a * b1 * b2)

        return monos[:]

    extra_monos = get_extra_monomials(level)

    # Create and solve SDP relaxation at fixed level=0
    sdp = ncp.SdpRelaxation(ops, verbose=int(verbose), normalized=True, parallel=0)
    sdp.get_relaxation(
        level=0,
        equalities=op_eqs[:],
        inequalities=op_ineqs[:],
        momentequalities=moment_eqs[:],
        momentinequalities=moment_ineqs[:],
        objective=-obj,
        substitutions=subs,
        extramonomials=extra_monos
    )
    sdp.solve(solver="mosek")

    return -sdp.primal, -sdp.dual, sdp.status

# %% [markdown]
# ## Testing Vertices

# %%
# Load the JSON file
with open("vertexCoords.json", "r") as f:
    data = json.load(f)

# %%
theta = np.pi / 4
tolerance = 1e-6
levels = [0, 'AA', 'BB', 'AB', 'BB+AB', 'ABB', 'AAB', 'AB+ABB', 'AA+AB+ABB', 'BB+AB+ABB', 'AA+BB+AB+ABB', 'AB+AAB+ABB']

with open("vertexCoords.json", "r") as f:
    local_vertices_data = json.load(f)

local_verts = None
for theta_value, verts in local_vertices_data:
    if abs(theta_value - theta) < tolerance:
        local_verts = np.array(verts)
        break

if local_verts is None:
    raise ValueError(f"No local polytope found for theta = {theta}")

print(f"Found {len(local_verts)} local vertices for θ = {theta:.6f}")

for i, (r0, r1) in enumerate(local_verts):
    print(f"\n--- Vertex #{i+1}: (r0 = {r0:.6f}, r1 = {r1:.6f}) ---")
    for lvl in levels:
        p, d, s = test_point_quantum_bound(theta, r0, r1, level=lvl)
        print(f"  Level {lvl:<12}: primal = {p:.10f}, dual = {d:.10f}, status = {s}")
# Out:
# Found 8 local vertices for θ = 0.785398
#
# --- Vertex #1: (r0 = 0.000000, r1 = 0.292893) ---
#   Level 0           : primal = 1.0857864377, dual = 1.0857864365, status = optimal
#   Level AA          : primal = 1.0857864379, dual = 1.0857864367, status = optimal
#   Level BB          : primal = 1.0857864383, dual = 1.0857864346, status = optimal
#   Level AB          : primal = 1.0091153569, dual = 1.0091153431, status = optimal
#   Level BB+AB       : primal = 1.0091153531, dual = 1.0091153512, status = optimal
#   Level ABB         : primal = 1.0857864420, dual = 1.0857864355, status = optimal
#   Level AAB         : primal = 1.0828606998, dual = 1.0828606844, status = optimal
#   Level AB+ABB      : primal = 1.0000000084, dual = 0.9999999940, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000012, dual = 0.9999999992, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000014, dual = 0.9999999990, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000006, dual = 0.9999999993, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000015, dual = 0.9999999990, status = optimal
#
# --- Vertex #2: (r0 = -0.207107, r1 = 0.207107) ---
#   Level 0           : primal = 1.0857864377, dual = 1.0857864365, status = optimal
#   Level AA          : primal = 1.0857864383, dual = 1.0857864346, status = optimal
#   Level BB          : primal = 1.0857864379, dual = 1.0857864367, status = optimal
#   Level AB          : primal = 1.0091153569, dual = 1.0091153431, status = optimal
#   Level BB+AB       : primal = 1.0091153543, dual = 1.0091153494, status = optimal
#   Level ABB         : primal = 1.0828606998, dual = 1.0828606844, status = optimal
#   Level AAB         : primal = 1.0857864420, dual = 1.0857864355, status = optimal
#   Level AB+ABB      : primal = 1.0008911036, dual = 1.0008910972, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000012, dual = 0.9999999991, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000041, dual = 0.9999999971, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000013, dual = 0.9999999984, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000016, dual = 0.9999999990, status = optimal
#
# --- Vertex #3: (r0 = 0.292893, r1 = 0.000000) ---
#   Level 0           : primal = 1.0857864377, dual = 1.0857864365, status = optimal
#   Level AA          : primal = 1.0857864379, dual = 1.0857864367, status = optimal
#   Level BB          : primal = 1.0857864383, dual = 1.0857864346, status = optimal
#   Level AB          : primal = 1.0091153569, dual = 1.0091153431, status = optimal
#   Level BB+AB       : primal = 1.0091153531, dual = 1.0091153512, status = optimal
#   Level ABB         : primal = 1.0857864420, dual = 1.0857864355, status = optimal
#   Level AAB         : primal = 1.0828606998, dual = 1.0828606844, status = optimal
#   Level AB+ABB      : primal = 1.0000000083, dual = 0.9999999940, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000010, dual = 0.9999999994, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000014, dual = 0.9999999990, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000007, dual = 0.9999999993, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000015, dual = 0.9999999990, status = optimal
#
# --- Vertex #4: (r0 = 0.207107, r1 = -0.207107) ---
#   Level 0           : primal = 1.0857864377, dual = 1.0857864365, status = optimal
#   Level AA          : primal = 1.0857864383, dual = 1.0857864346, status = optimal
#   Level BB          : primal = 1.0857864379, dual = 1.0857864367, status = optimal
#   Level AB          : primal = 1.0091153569, dual = 1.0091153431, status = optimal
#   Level BB+AB       : primal = 1.0091153543, dual = 1.0091153494, status = optimal
#   Level ABB         : primal = 1.0828606998, dual = 1.0828606844, status = optimal
#   Level AAB         : primal = 1.0857864420, dual = 1.0857864355, status = optimal
#   Level AB+ABB      : primal = 1.0008911036, dual = 1.0008910972, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000012, dual = 0.9999999991, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000037, dual = 0.9999999973, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000010, dual = 0.9999999980, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000015, dual = 0.9999999990, status = optimal
#
# --- Vertex #5: (r0 = -0.207107, r1 = -0.207107) ---
#   Level 0           : primal = 1.0857864377, dual = 1.0857864365, status = optimal
#   Level AA          : primal = 1.0857864383, dual = 1.0857864346, status = optimal
#   Level BB          : primal = 1.0857864379, dual = 1.0857864367, status = optimal
#   Level AB          : primal = 1.0091153569, dual = 1.0091153431, status = optimal
#   Level BB+AB       : primal = 1.0091153543, dual = 1.0091153494, status = optimal
#   Level ABB         : primal = 1.0828606998, dual = 1.0828606844, status = optimal
#   Level AAB         : primal = 1.0857864420, dual = 1.0857864355, status = optimal
#   Level AB+ABB      : primal = 1.0008911036, dual = 1.0008910972, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000002, dual = 0.9999999997, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000041, dual = 0.9999999971, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000012, dual = 0.9999999984, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000015, dual = 0.9999999990, status = optimal
#
# --- Vertex #6: (r0 = 0.000000, r1 = -0.292893) ---
#   Level 0           : primal = 1.0857864377, dual = 1.0857864365, status = optimal
#   Level AA          : primal = 1.0857864379, dual = 1.0857864367, status = optimal
#   Level BB          : primal = 1.0857864383, dual = 1.0857864346, status = optimal
#   Level AB          : primal = 1.0091153569, dual = 1.0091153431, status = optimal
#   Level BB+AB       : primal = 1.0091153531, dual = 1.0091153512, status = optimal
#   Level ABB         : primal = 1.0857864420, dual = 1.0857864355, status = optimal
#   Level AAB         : primal = 1.0828606998, dual = 1.0828606844, status = optimal
#   Level AB+ABB      : primal = 1.0000000083, dual = 0.9999999940, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000012, dual = 0.9999999988, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000014, dual = 0.9999999990, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000007, dual = 0.9999999993, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000014, dual = 0.9999999990, status = optimal
#
# --- Vertex #7: (r0 = 0.207107, r1 = 0.207107) ---
#   Level 0           : primal = 1.0857864377, dual = 1.0857864365, status = optimal
#   Level AA          : primal = 1.0857864383, dual = 1.0857864346, status = optimal
#   Level BB          : primal = 1.0857864379, dual = 1.0857864367, status = optimal
#   Level AB          : primal = 1.0091153569, dual = 1.0091153431, status = optimal
#   Level BB+AB       : primal = 1.0091153543, dual = 1.0091153494, status = optimal
#   Level ABB         : primal = 1.0828606998, dual = 1.0828606844, status = optimal
#   Level AAB         : primal = 1.0857864420, dual = 1.0857864355, status = optimal
#   Level AB+ABB      : primal = 1.0008911036, dual = 1.0008910972, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000013, dual = 0.9999999989, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000038, dual = 0.9999999972, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000023, dual = 0.9999999948, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000015, dual = 0.9999999990, status = optimal
#
# --- Vertex #8: (r0 = -0.292893, r1 = 0.000000) ---
#   Level 0           : primal = 1.0857864377, dual = 1.0857864365, status = optimal
#   Level AA          : primal = 1.0857864379, dual = 1.0857864367, status = optimal
#   Level BB          : primal = 1.0857864383, dual = 1.0857864346, status = optimal
#   Level AB          : primal = 1.0091153569, dual = 1.0091153431, status = optimal
#   Level BB+AB       : primal = 1.0091153531, dual = 1.0091153512, status = optimal
#   Level ABB         : primal = 1.0857864420, dual = 1.0857864355, status = optimal
#   Level AAB         : primal = 1.0828606998, dual = 1.0828606844, status = optimal
#   Level AB+ABB      : primal = 1.0000000084, dual = 0.9999999940, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000008, dual = 0.9999999993, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000014, dual = 0.9999999990, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000007, dual = 0.9999999993, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000015, dual = 0.9999999990, status = optimal

# %%
theta = np.pi / 8 + 7*np.pi / (64)
tolerance = 1e-6
levels = [0, 'AA', 'BB', 'AB', 'BB+AB', 'ABB', 'AAB', 'AB+ABB', 'AA+AB+ABB', 'BB+AB+ABB', 'AA+BB+AB+ABB', 'AB+AAB+ABB']


with open("vertexCoords.json", "r") as f:
    local_vertices_data = json.load(f)

local_verts = None
for theta_value, verts in local_vertices_data:
    if abs(theta_value - theta) < tolerance:
        local_verts = np.array(verts)
        break

if local_verts is None:
    raise ValueError(f"No local polytope found for theta = {theta}")

print(f"Found {len(local_verts)} local vertices for θ = {theta:.6f}")

for i, (r0, r1) in enumerate(local_verts):
    print(f"\n--- Vertex #{i+1}: (r0 = {r0:.6f}, r1 = {r1:.6f}) ---")
    for lvl in levels:
        p, d, s = test_point_quantum_bound(theta, r0, r1, level=lvl)
        print(f"  Level {lvl:<12}: primal = {p:.10f}, dual = {d:.10f}, status = {s}")
# Out:
# Found 8 local vertices for θ = 0.736311
#
# --- Vertex #1: (r0 = -0.019962, r1 = 0.294916) ---
#   Level 0           : primal = 1.1173009003, dual = 1.1173008978, status = optimal
#   Level AA          : primal = 1.1100970986, dual = 1.1100970950, status = optimal
#   Level BB          : primal = 1.1146679937, dual = 1.1146679865, status = optimal
#   Level AB          : primal = 1.0097272452, dual = 1.0097272426, status = optimal
#   Level BB+AB       : primal = 1.0097272464, dual = 1.0097272422, status = optimal
#   Level ABB         : primal = 1.0957463807, dual = 1.0957463766, status = optimal
#   Level AAB         : primal = 1.0893883795, dual = 1.0893883667, status = optimal
#   Level AB+ABB      : primal = 1.0000606163, dual = 1.0000606142, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000020, dual = 0.9999999986, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000011, dual = 0.9999999993, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000009, dual = 0.9999999990, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000029, dual = 0.9999999978, status = optimal
#
# --- Vertex #2: (r0 = -0.159806, r1 = 0.234896) ---
#   Level 0           : primal = 1.1134838338, dual = 1.1134838316, status = optimal
#   Level AA          : primal = 1.1089109667, dual = 1.1089109617, status = optimal
#   Level BB          : primal = 1.1092437695, dual = 1.1092437605, status = optimal
#   Level AB          : primal = 1.0103337487, dual = 1.0103337461, status = optimal
#   Level BB+AB       : primal = 1.0103337502, dual = 1.0103337447, status = optimal
#   Level ABB         : primal = 1.0866556541, dual = 1.0866556496, status = optimal
#   Level AAB         : primal = 1.0976494972, dual = 1.0976494815, status = optimal
#   Level AB+ABB      : primal = 1.0014455943, dual = 1.0014455922, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000030, dual = 0.9999999977, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000013, dual = 0.9999999990, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000010, dual = 0.9999999984, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000029, dual = 0.9999999979, status = optimal
#
# --- Vertex #3: (r0 = 0.321421, r1 = 0.000000) ---
#   Level 0           : primal = 1.0977114636, dual = 1.0977114600, status = optimal
#   Level AA          : primal = 1.0977114714, dual = 1.0977114571, status = optimal
#   Level BB          : primal = 1.0977114687, dual = 1.0977114520, status = optimal
#   Level AB          : primal = 1.0103374329, dual = 1.0103374145, status = optimal
#   Level BB+AB       : primal = 1.0103374283, dual = 1.0103374248, status = optimal
#   Level ABB         : primal = 1.0968440180, dual = 1.0968440119, status = optimal
#   Level AAB         : primal = 1.0788084315, dual = 1.0788084300, status = optimal
#   Level AB+ABB      : primal = 1.0000000048, dual = 0.9999999949, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000021, dual = 0.9999999985, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000010, dual = 0.9999999993, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000009, dual = 0.9999999991, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000016, dual = 0.9999999990, status = optimal
#
# --- Vertex #4: (r0 = 0.250543, r1 = -0.185193) ---
#   Level 0           : primal = 1.1087116840, dual = 1.1087116741, status = optimal
#   Level AA          : primal = 1.1086749834, dual = 1.1086749817, status = optimal
#   Level BB          : primal = 1.1038564966, dual = 1.1038564939, status = optimal
#   Level AB          : primal = 1.0084877587, dual = 1.0084877431, status = optimal
#   Level BB+AB       : primal = 1.0084877549, dual = 1.0084877493, status = optimal
#   Level ABB         : primal = 1.0885514698, dual = 1.0885514534, status = optimal
#   Level AAB         : primal = 1.0908227343, dual = 1.0908227309, status = optimal
#   Level AB+ABB      : primal = 1.0005995519, dual = 1.0005995429, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000018, dual = 0.9999999981, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000015, dual = 0.9999999991, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000017, dual = 0.9999999981, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000024, dual = 0.9999999982, status = optimal
#
# --- Vertex #5: (r0 = -0.159806, r1 = -0.234896) ---
#   Level 0           : primal = 1.1134838338, dual = 1.1134838316, status = optimal
#   Level AA          : primal = 1.1089109667, dual = 1.1089109617, status = optimal
#   Level BB          : primal = 1.1092437695, dual = 1.1092437605, status = optimal
#   Level AB          : primal = 1.0103337487, dual = 1.0103337461, status = optimal
#   Level BB+AB       : primal = 1.0103337502, dual = 1.0103337447, status = optimal
#   Level ABB         : primal = 1.0866556541, dual = 1.0866556496, status = optimal
#   Level AAB         : primal = 1.0976494972, dual = 1.0976494815, status = optimal
#   Level AB+ABB      : primal = 1.0014455943, dual = 1.0014455922, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000028, dual = 0.9999999978, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000001, dual = 0.9999999993, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000049, dual = 0.9999999929, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000029, dual = 0.9999999979, status = optimal
#
# --- Vertex #6: (r0 = -0.019962, r1 = -0.294916) ---
#   Level 0           : primal = 1.1173009003, dual = 1.1173008978, status = optimal
#   Level AA          : primal = 1.1100970986, dual = 1.1100970950, status = optimal
#   Level BB          : primal = 1.1146679937, dual = 1.1146679865, status = optimal
#   Level AB          : primal = 1.0097272452, dual = 1.0097272426, status = optimal
#   Level BB+AB       : primal = 1.0097272464, dual = 1.0097272422, status = optimal
#   Level ABB         : primal = 1.0957463807, dual = 1.0957463766, status = optimal
#   Level AAB         : primal = 1.0893883795, dual = 1.0893883667, status = optimal
#   Level AB+ABB      : primal = 1.0000606162, dual = 1.0000606142, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000020, dual = 0.9999999986, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000011, dual = 0.9999999993, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000009, dual = 0.9999999989, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000029, dual = 0.9999999978, status = optimal
#
# --- Vertex #7: (r0 = 0.250543, r1 = 0.185193) ---
#   Level 0           : primal = 1.1087116840, dual = 1.1087116741, status = optimal
#   Level AA          : primal = 1.1086749834, dual = 1.1086749817, status = optimal
#   Level BB          : primal = 1.1038564966, dual = 1.1038564939, status = optimal
#   Level AB          : primal = 1.0084877587, dual = 1.0084877431, status = optimal
#   Level BB+AB       : primal = 1.0084877549, dual = 1.0084877493, status = optimal
#   Level ABB         : primal = 1.0885514698, dual = 1.0885514534, status = optimal
#   Level AAB         : primal = 1.0908227343, dual = 1.0908227309, status = optimal
#   Level AB+ABB      : primal = 1.0005995519, dual = 1.0005995429, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000018, dual = 0.9999999981, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000014, dual = 0.9999999991, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000015, dual = 0.9999999981, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000023, dual = 0.9999999982, status = optimal
#
# --- Vertex #8: (r0 = -0.263166, r1 = 0.000000) ---
#   Level 0           : primal = 1.0885461487, dual = 1.0885461344, status = optimal
#   Level AA          : primal = 1.0885461543, dual = 1.0885461412, status = optimal
#   Level BB          : primal = 1.0885461540, dual = 1.0885461407, status = optimal
#   Level AB          : primal = 1.0078520184, dual = 1.0078520017, status = optimal
#   Level BB+AB       : primal = 1.0078520184, dual = 1.0078520075, status = optimal
#   Level ABB         : primal = 1.0866326295, dual = 1.0866326252, status = optimal
#   Level AAB         : primal = 1.0868232044, dual = 1.0868231996, status = optimal
#   Level AB+ABB      : primal = 1.0000000023, dual = 0.9999999991, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000015, dual = 0.9999999979, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000019, dual = 0.9999999987, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000004, dual = 0.9999999996, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000020, dual = 0.9999999985, status = optimal

# %%
theta = np.pi / 8 + 6*np.pi / (64)
tolerance = 1e-6
levels = [0, 'AA', 'BB', 'AB', 'BB+AB', 'ABB', 'AAB', 'AB+ABB', 'AA+AB+ABB', 'BB+AB+ABB', 'AA+BB+AB+ABB', 'AB+AAB+ABB']

with open("vertexCoords.json", "r") as f:
    local_vertices_data = json.load(f)

local_verts = None
for theta_value, verts in local_vertices_data:
    if abs(theta_value - theta) < tolerance:
        local_verts = np.array(verts)
        break

if local_verts is None:
    raise ValueError(f"No local polytope found for theta = {theta}")

print(f"Found {len(local_verts)} local vertices for θ = {theta:.6f}")

for i, (r0, r1) in enumerate(local_verts):
    print(f"\n--- Vertex #{i+1}: (r0 = {r0:.6f}, r1 = {r1:.6f}) ---")
    for lvl in levels:
        p, d, s = test_point_quantum_bound(theta, r0, r1, level=lvl)
        print(f"  Level {lvl:<12}: primal = {p:.10f}, dual = {d:.10f}, status = {s}")
# Out:
# Found 8 local vertices for θ = 0.687223
#
# --- Vertex #1: (r0 = -0.037597, r1 = 0.301323) ---
#   Level 0           : primal = 1.1491171455, dual = 1.1491171406, status = optimal
#   Level AA          : primal = 1.1365835595, dual = 1.1365835530, status = optimal
#   Level BB          : primal = 1.1461564028, dual = 1.1461563978, status = optimal
#   Level AB          : primal = 1.0117711974, dual = 1.0117711782, status = optimal
#   Level BB+AB       : primal = 1.0117711873, dual = 1.0117711838, status = optimal
#   Level ABB         : primal = 1.1068884791, dual = 1.1068884759, status = optimal
#   Level AAB         : primal = 1.1068173119, dual = 1.1068173081, status = optimal
#   Level AB+ABB      : primal = 1.0005096592, dual = 1.0005096565, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000042, dual = 0.9999999972, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000052, dual = 0.9999999960, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000021, dual = 0.9999999978, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000048, dual = 0.9999999953, status = optimal
#
# --- Vertex #2: (r0 = -0.105336, r1 = 0.270836) ---
#   Level 0           : primal = 1.1453288704, dual = 1.1453288530, status = optimal
#   Level AA          : primal = 1.1347998609, dual = 1.1347998557, status = optimal
#   Level BB          : primal = 1.1404772393, dual = 1.1404772203, status = optimal
#   Level AB          : primal = 1.0124600123, dual = 1.0124600076, status = optimal
#   Level BB+AB       : primal = 1.0124600111, dual = 1.0124600077, status = optimal
#   Level ABB         : primal = 1.1004078091, dual = 1.1004077993, status = optimal
#   Level AAB         : primal = 1.1114477280, dual = 1.1114477252, status = optimal
#   Level AB+ABB      : primal = 1.0018640186, dual = 1.0018640136, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000083, dual = 0.9999999937, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000028, dual = 0.9999999976, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000031, dual = 0.9999999966, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000057, dual = 0.9999999943, status = optimal
#
# --- Vertex #3: (r0 = 0.350876, r1 = 0.000000) ---
#   Level 0           : primal = 1.1245726994, dual = 1.1245726960, status = optimal
#   Level AA          : primal = 1.1224677184, dual = 1.1224677043, status = optimal
#   Level BB          : primal = 1.1245726991, dual = 1.1245726976, status = optimal
#   Level AB          : primal = 1.0114311546, dual = 1.0114311497, status = optimal
#   Level BB+AB       : primal = 1.0114311558, dual = 1.0114311505, status = optimal
#   Level ABB         : primal = 1.1114022667, dual = 1.1114022548, status = optimal
#   Level AAB         : primal = 1.0765649517, dual = 1.0765649412, status = optimal
#   Level AB+ABB      : primal = 1.0000000057, dual = 0.9999999937, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000033, dual = 0.9999999969, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000016, dual = 0.9999999989, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000009, dual = 0.9999999992, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000038, dual = 0.9999999967, status = optimal
#
# --- Vertex #4: (r0 = 0.292880, r1 = -0.167605) ---
#   Level 0           : primal = 1.1387037961, dual = 1.1387037857, status = optimal
#   Level AA          : primal = 1.1349965240, dual = 1.1349965175, status = optimal
#   Level BB          : primal = 1.1342728035, dual = 1.1342727950, status = optimal
#   Level AB          : primal = 1.0082597902, dual = 1.0082597875, status = optimal
#   Level BB+AB       : primal = 1.0082597915, dual = 1.0082597863, status = optimal
#   Level ABB         : primal = 1.0987279770, dual = 1.0987279744, status = optimal
#   Level AAB         : primal = 1.0969143296, dual = 1.0969143228, status = optimal
#   Level AB+ABB      : primal = 1.0006549743, dual = 1.0006549720, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000021, dual = 0.9999999974, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000013, dual = 0.9999999992, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000034, dual = 0.9999999967, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000027, dual = 0.9999999978, status = optimal
#
# --- Vertex #5: (r0 = -0.105336, r1 = -0.270836) ---
#   Level 0           : primal = 1.1453288704, dual = 1.1453288530, status = optimal
#   Level AA          : primal = 1.1347998609, dual = 1.1347998557, status = optimal
#   Level BB          : primal = 1.1404772393, dual = 1.1404772203, status = optimal
#   Level AB          : primal = 1.0124600123, dual = 1.0124600076, status = optimal
#   Level BB+AB       : primal = 1.0124600111, dual = 1.0124600077, status = optimal
#   Level ABB         : primal = 1.1004078091, dual = 1.1004077993, status = optimal
#   Level AAB         : primal = 1.1114477280, dual = 1.1114477252, status = optimal
#   Level AB+ABB      : primal = 1.0018640186, dual = 1.0018640136, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000082, dual = 0.9999999937, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000022, dual = 0.9999999978, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000030, dual = 0.9999999966, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000057, dual = 0.9999999943, status = optimal
#
# --- Vertex #6: (r0 = -0.037597, r1 = -0.301323) ---
#   Level 0           : primal = 1.1491171455, dual = 1.1491171406, status = optimal
#   Level AA          : primal = 1.1365835595, dual = 1.1365835530, status = optimal
#   Level BB          : primal = 1.1461564028, dual = 1.1461563978, status = optimal
#   Level AB          : primal = 1.0117711974, dual = 1.0117711782, status = optimal
#   Level BB+AB       : primal = 1.0117711873, dual = 1.0117711838, status = optimal
#   Level ABB         : primal = 1.1068884791, dual = 1.1068884759, status = optimal
#   Level AAB         : primal = 1.1068173119, dual = 1.1068173081, status = optimal
#   Level AB+ABB      : primal = 1.0005096592, dual = 1.0005096565, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000042, dual = 0.9999999972, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000052, dual = 0.9999999960, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000021, dual = 0.9999999978, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000048, dual = 0.9999999953, status = optimal
#
# --- Vertex #7: (r0 = 0.292880, r1 = 0.167605) ---
#   Level 0           : primal = 1.1387037961, dual = 1.1387037857, status = optimal
#   Level AA          : primal = 1.1349965240, dual = 1.1349965175, status = optimal
#   Level BB          : primal = 1.1342728035, dual = 1.1342727950, status = optimal
#   Level AB          : primal = 1.0082597896, dual = 1.0082597876, status = optimal
#   Level BB+AB       : primal = 1.0082597915, dual = 1.0082597863, status = optimal
#   Level ABB         : primal = 1.0987279770, dual = 1.0987279744, status = optimal
#   Level AAB         : primal = 1.0969143296, dual = 1.0969143228, status = optimal
#   Level AB+ABB      : primal = 1.0006549743, dual = 1.0006549720, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000020, dual = 0.9999999971, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000045, dual = 0.9999999975, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000040, dual = 0.9999999960, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000027, dual = 0.9999999978, status = optimal
#
# --- Vertex #8: (r0 = -0.229731, r1 = 0.000000) ---
#   Level 0           : primal = 1.1099891244, dual = 1.1099891195, status = optimal
#   Level AA          : primal = 1.1050510947, dual = 1.1050510852, status = optimal
#   Level BB          : primal = 1.1099891257, dual = 1.1099891223, status = optimal
#   Level AB          : primal = 1.0066041938, dual = 1.0066041917, status = optimal
#   Level BB+AB       : primal = 1.0066041993, dual = 1.0066041890, status = optimal
#   Level ABB         : primal = 1.0859948723, dual = 1.0859948553, status = optimal
#   Level AAB         : primal = 1.0883449928, dual = 1.0883449894, status = optimal
#   Level AB+ABB      : primal = 1.0000000103, dual = 0.9999999983, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000068, dual = 0.9999999941, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000028, dual = 0.9999999976, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000004, dual = 0.9999999997, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000029, dual = 0.9999999977, status = optimal

# %%
theta = np.pi / 8 + 5*np.pi / (64)
tolerance = 1e-6
levels = [0, 'AA', 'BB', 'AB', 'BB+AB', 'ABB', 'AAB', 'AB+ABB', 'AA+AB+ABB', 'BB+AB+ABB', 'AA+BB+AB+ABB', 'AB+AAB+ABB']

with open("vertexCoords.json", "r") as f:
    local_vertices_data = json.load(f)

local_verts = None
for theta_value, verts in local_vertices_data:
    if abs(theta_value - theta) < tolerance:
        local_verts = np.array(verts)
        break

if local_verts is None:
    raise ValueError(f"No local polytope found for theta = {theta}")

print(f"Found {len(local_verts)} local vertices for θ = {theta:.6f}")

for i, (r0, r1) in enumerate(local_verts):
    print(f"\n--- Vertex #{i+1}: (r0 = {r0:.6f}, r1 = {r1:.6f}) ---")
    for lvl in levels:
        p, d, s = test_point_quantum_bound(theta, r0, r1, level=lvl)
        print(f"  Level {lvl:<12}: primal = {p:.10f}, dual = {d:.10f}, status = {s}")
# Out:
# Found 6 local vertices for θ = 0.638136
#
# --- Vertex #1: (r0 = 0.383354, r1 = 0.000000) ---
#   Level 0           : primal = 1.1658943478, dual = 1.1658943272, status = optimal
#   Level AA          : primal = 1.1480300095, dual = 1.1480300012, status = optimal
#   Level BB          : primal = 1.1658943401, dual = 1.1658943297, status = optimal
#   Level AB          : primal = 1.0122647413, dual = 1.0122647327, status = optimal
#   Level BB+AB       : primal = 1.0122647422, dual = 1.0122647339, status = optimal
#   Level ABB         : primal = 1.1280058457, dual = 1.1280058378, status = optimal
#   Level AAB         : primal = 1.0763199724, dual = 1.0763199661, status = optimal
#   Level AB+ABB      : primal = 1.0000000047, dual = 0.9999999946, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000061, dual = 0.9999999929, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000015, dual = 0.9999999989, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000015, dual = 0.9999999989, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000055, dual = 0.9999999954, status = optimal
#
# --- Vertex #2: (r0 = 0.336718, r1 = -0.153257) ---
#   Level 0           : primal = 1.1735549382, dual = 1.1735549357, status = optimal
#   Level AA          : primal = 1.1612209006, dual = 1.1612208924, status = optimal
#   Level BB          : primal = 1.1711194181, dual = 1.1711194091, status = optimal
#   Level AB          : primal = 1.0082722930, dual = 1.0082722731, status = optimal
#   Level BB+AB       : primal = 1.0082722835, dual = 1.0082722796, status = optimal
#   Level ABB         : primal = 1.1142511338, dual = 1.1142511218, status = optimal
#   Level AAB         : primal = 1.1042759023, dual = 1.1042758934, status = optimal
#   Level AB+ABB      : primal = 1.0007128892, dual = 1.0007128760, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000051, dual = 0.9999999937, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000018, dual = 0.9999999989, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000060, dual = 0.9999999940, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000036, dual = 0.9999999970, status = optimal
#
# --- Vertex #3: (r0 = 0.336718, r1 = 0.153257) ---
#   Level 0           : primal = 1.1735549382, dual = 1.1735549357, status = optimal
#   Level AA          : primal = 1.1612209006, dual = 1.1612208924, status = optimal
#   Level BB          : primal = 1.1711194181, dual = 1.1711194091, status = optimal
#   Level AB          : primal = 1.0082722930, dual = 1.0082722731, status = optimal
#   Level BB+AB       : primal = 1.0082722835, dual = 1.0082722796, status = optimal
#   Level ABB         : primal = 1.1142511338, dual = 1.1142511218, status = optimal
#   Level AAB         : primal = 1.1042759023, dual = 1.1042758934, status = optimal
#   Level AB+ABB      : primal = 1.0007128892, dual = 1.0007128760, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000051, dual = 0.9999999937, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000016, dual = 0.9999999990, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000059, dual = 0.9999999940, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000035, dual = 0.9999999970, status = optimal
#
# --- Vertex #4: (r0 = -0.189162, r1 = 0.000000) ---
#   Level 0           : primal = 1.1369521326, dual = 1.1369521360, status = optimal
#   Level AA          : primal = 1.1217365498, dual = 1.1217365471, status = optimal
#   Level BB          : primal = 1.1369521533, dual = 1.1369521402, status = optimal
#   Level AB          : primal = 1.0054072955, dual = 1.0054072896, status = optimal
#   Level BB+AB       : primal = 1.0054073022, dual = 1.0054072848, status = optimal
#   Level ABB         : primal = 1.0795986507, dual = 1.0795986324, status = optimal
#   Level AAB         : primal = 1.0869563607, dual = 1.0869563412, status = optimal
#   Level AB+ABB      : primal = 1.0000000092, dual = 0.9999999964, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000028, dual = 0.9999999978, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000039, dual = 0.9999999959, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000003, dual = 0.9999999995, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000065, dual = 0.9999999944, status = optimal
#
# --- Vertex #5: (r0 = -0.043111, r1 = -0.310419) ---
#   Level 0           : primal = 1.1787260940, dual = 1.1787260857, status = optimal
#   Level AA          : primal = 1.1621071497, dual = 1.1621071434, status = optimal
#   Level BB          : primal = 1.1765682569, dual = 1.1765682557, status = optimal
#   Level AB          : primal = 1.0145851994, dual = 1.0145851946, status = optimal
#   Level BB+AB       : primal = 1.0145851986, dual = 1.0145851954, status = optimal
#   Level ABB         : primal = 1.1168242687, dual = 1.1168242651, status = optimal
#   Level AAB         : primal = 1.1257326588, dual = 1.1257326523, status = optimal
#   Level AB+ABB      : primal = 1.0020701844, dual = 1.0020701765, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000074, dual = 0.9999999968, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000021, dual = 0.9999999979, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000092, dual = 0.9999999920, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000040, dual = 0.9999999962, status = optimal
#
# --- Vertex #6: (r0 = -0.043111, r1 = 0.310419) ---
#   Level 0           : primal = 1.1787260940, dual = 1.1787260857, status = optimal
#   Level AA          : primal = 1.1621071497, dual = 1.1621071434, status = optimal
#   Level BB          : primal = 1.1765682569, dual = 1.1765682557, status = optimal
#   Level AB          : primal = 1.0145851994, dual = 1.0145851946, status = optimal
#   Level BB+AB       : primal = 1.0145851986, dual = 1.0145851954, status = optimal
#   Level ABB         : primal = 1.1168242687, dual = 1.1168242651, status = optimal
#   Level AAB         : primal = 1.1257326588, dual = 1.1257326523, status = optimal
#   Level AB+ABB      : primal = 1.0020701844, dual = 1.0020701765, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000019, dual = 0.9999999986, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000024, dual = 0.9999999979, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000092, dual = 0.9999999920, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000040, dual = 0.9999999962, status = optimal

# %%
theta = np.pi / 8 + 4*np.pi / (64)
tolerance = 1e-6
levels = [0, 'AA', 'BB', 'AB', 'BB+AB', 'ABB', 'AAB', 'AB+ABB', 'AA+AB+ABB', 'BB+AB+ABB', 'AA+BB+AB+ABB', 'AB+AAB+ABB']

with open("vertexCoords.json", "r") as f:
    local_vertices_data = json.load(f)

local_verts = None
for theta_value, verts in local_vertices_data:
    if abs(theta_value - theta) < tolerance:
        local_verts = np.array(verts)
        break

if local_verts is None:
    raise ValueError(f"No local polytope found for theta = {theta}")

print(f"Found {len(local_verts)} local vertices for θ = {theta:.6f}")

for i, (r0, r1) in enumerate(local_verts):
    print(f"\n--- Vertex #{i+1}: (r0 = {r0:.6f}, r1 = {r1:.6f}) ---")
    for lvl in levels:
        p, d, s = test_point_quantum_bound(theta, r0, r1, level=lvl)
        print(f"  Level {lvl:<12}: primal = {p:.10f}, dual = {d:.10f}, status = {s}")
# Out:
# Found 6 local vertices for θ = 0.589049
#
# --- Vertex #1: (r0 = 0.421218, r1 = 0.000000) ---
#   Level 0           : primal = 1.2089273707, dual = 1.2089273633, status = optimal
#   Level AA          : primal = 1.1720264585, dual = 1.1720264438, status = optimal
#   Level BB          : primal = 1.2089273714, dual = 1.2089273658, status = optimal
#   Level AB          : primal = 1.0126383879, dual = 1.0126383815, status = optimal
#   Level BB+AB       : primal = 1.0126383922, dual = 1.0126383802, status = optimal
#   Level ABB         : primal = 1.1488761855, dual = 1.1488761783, status = optimal
#   Level AAB         : primal = 1.0809695991, dual = 1.0809695789, status = optimal
#   Level AB+ABB      : primal = 1.0000000053, dual = 0.9999999939, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000069, dual = 0.9999999957, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000017, dual = 0.9999999987, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000050, dual = 0.9999999960, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000067, dual = 0.9999999935, status = optimal
#
# --- Vertex #2: (r0 = 0.384824, r1 = -0.141363) ---
#   Level 0           : primal = 1.2122201373, dual = 1.2122201344, status = optimal
#   Level AA          : primal = 1.1869881225, dual = 1.1869881138, status = optimal
#   Level BB          : primal = 1.2108093947, dual = 1.2108093827, status = optimal
#   Level AB          : primal = 1.0083480385, dual = 1.0083480256, status = optimal
#   Level BB+AB       : primal = 1.0083480327, dual = 1.0083480293, status = optimal
#   Level ABB         : primal = 1.1351888021, dual = 1.1351887964, status = optimal
#   Level AAB         : primal = 1.1147097917, dual = 1.1147097864, status = optimal
#   Level AB+ABB      : primal = 1.0007258855, dual = 1.0007258744, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000020, dual = 0.9999999981, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000020, dual = 0.9999999982, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000009, dual = 0.9999999992, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000060, dual = 0.9999999946, status = optimal
#
# --- Vertex #3: (r0 = 0.384824, r1 = 0.141363) ---
#   Level 0           : primal = 1.2122201374, dual = 1.2122201345, status = optimal
#   Level AA          : primal = 1.1869881225, dual = 1.1869881138, status = optimal
#   Level BB          : primal = 1.2108093947, dual = 1.2108093827, status = optimal
#   Level AB          : primal = 1.0083480385, dual = 1.0083480256, status = optimal
#   Level BB+AB       : primal = 1.0083480327, dual = 1.0083480293, status = optimal
#   Level ABB         : primal = 1.1351888021, dual = 1.1351887964, status = optimal
#   Level AAB         : primal = 1.1147097917, dual = 1.1147097864, status = optimal
#   Level AB+ABB      : primal = 1.0007258855, dual = 1.0007258744, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000020, dual = 0.9999999981, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000022, dual = 0.9999999982, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000011, dual = 0.9999999991, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000060, dual = 0.9999999946, status = optimal
#
# --- Vertex #4: (r0 = -0.136116, r1 = 0.000000) ---
#   Level 0           : primal = 1.1654577251, dual = 1.1654577065, status = optimal
#   Level AA          : primal = 1.1378247577, dual = 1.1378247564, status = optimal
#   Level BB          : primal = 1.1654577275, dual = 1.1654577250, status = optimal
#   Level AB          : primal = 1.0042803407, dual = 1.0042803300, status = optimal
#   Level BB+AB       : primal = 1.0042803373, dual = 1.0042803325, status = optimal
#   Level ABB         : primal = 1.0662938368, dual = 1.0662938287, status = optimal
#   Level AAB         : primal = 1.0822045400, dual = 1.0822045326, status = optimal
#   Level AB+ABB      : primal = 1.0000000075, dual = 0.9999999952, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000051, dual = 0.9999999967, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000059, dual = 0.9999999943, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000039, dual = 0.9999999966, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000075, dual = 0.9999999938, status = optimal
#
# --- Vertex #5: (r0 = 0.008194, r1 = -0.306563) ---
#   Level 0           : primal = 1.2017889148, dual = 1.2017889131, status = optimal
#   Level AA          : primal = 1.1767920472, dual = 1.1767920399, status = optimal
#   Level BB          : primal = 1.2016191779, dual = 1.2016191752, status = optimal
#   Level AB          : primal = 1.0086031971, dual = 1.0086031939, status = optimal
#   Level BB+AB       : primal = 1.0086032040, dual = 1.0086031886, status = optimal
#   Level ABB         : primal = 1.1113131574, dual = 1.1113131537, status = optimal
#   Level AAB         : primal = 1.1214738122, dual = 1.1214738087, status = optimal
#   Level AB+ABB      : primal = 1.0001159249, dual = 1.0001159121, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000021, dual = 0.9999999978, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000093, dual = 0.9999999902, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000053, dual = 0.9999999949, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000068, dual = 0.9999999928, status = optimal
#
# --- Vertex #6: (r0 = 0.008194, r1 = 0.306563) ---
#   Level 0           : primal = 1.2017889148, dual = 1.2017889131, status = optimal
#   Level AA          : primal = 1.1767920472, dual = 1.1767920399, status = optimal
#   Level BB          : primal = 1.2016191779, dual = 1.2016191752, status = optimal
#   Level AB          : primal = 1.0086031971, dual = 1.0086031939, status = optimal
#   Level BB+AB       : primal = 1.0086032040, dual = 1.0086031886, status = optimal
#   Level ABB         : primal = 1.1113131574, dual = 1.1113131537, status = optimal
#   Level AAB         : primal = 1.1214738122, dual = 1.1214738087, status = optimal
#   Level AB+ABB      : primal = 1.0001159249, dual = 1.0001159121, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000022, dual = 0.9999999977, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000093, dual = 0.9999999902, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000053, dual = 0.9999999949, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000068, dual = 0.9999999928, status = optimal

# %%
theta = np.pi / 8 + 3*np.pi / (64)
tolerance = 1e-6
levels = [0, 'AA', 'BB', 'AB', 'BB+AB', 'ABB', 'AAB', 'AB+ABB', 'AA+AB+ABB', 'BB+AB+ABB', 'AA+BB+AB+ABB', 'AB+AAB+ABB']

with open("vertexCoords.json", "r") as f:
    local_vertices_data = json.load(f)

local_verts = None
for theta_value, verts in local_vertices_data:
    if abs(theta_value - theta) < tolerance:
        local_verts = np.array(verts)
        break

if local_verts is None:
    raise ValueError(f"No local polytope found for theta = {theta}")

print(f"Found {len(local_verts)} local vertices for θ = {theta:.6f}")

for i, (r0, r1) in enumerate(local_verts):
    print(f"\n--- Vertex #{i+1}: (r0 = {r0:.6f}, r1 = {r1:.6f}) ---")
    for lvl in levels:
        p, d, s = test_point_quantum_bound(theta, r0, r1, level=lvl)
        print(f"  Level {lvl:<12}: primal = {p:.10f}, dual = {d:.10f}, status = {s}")
# Out:
# Found 6 local vertices for θ = 0.539961
#
# --- Vertex #1: (r0 = 0.467438, r1 = 0.000000) ---
#   Level 0           : primal = 1.2536100256, dual = 1.2536100109, status = optimal
#   Level AA          : primal = 1.1944582202, dual = 1.1944582145, status = optimal
#   Level BB          : primal = 1.2536100270, dual = 1.2536100097, status = optimal
#   Level AB          : primal = 1.0122457871, dual = 1.0122457844, status = optimal
#   Level BB+AB       : primal = 1.0122457927, dual = 1.0122457810, status = optimal
#   Level ABB         : primal = 1.1776818754, dual = 1.1776818630, status = optimal
#   Level AAB         : primal = 1.0945789478, dual = 1.0945789441, status = optimal
#   Level AB+ABB      : primal = 1.0000000042, dual = 0.9999999949, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000080, dual = 0.9999999934, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000021, dual = 0.9999999984, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000107, dual = 0.9999999913, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000009, dual = 0.9999999988, status = optimal
#
# --- Vertex #2: (r0 = 0.440508, r1 = -0.131335) ---
#   Level 0           : primal = 1.2546861821, dual = 1.2546861682, status = optimal
#   Level AA          : primal = 1.2119703129, dual = 1.2119703056, status = optimal
#   Level BB          : primal = 1.2538476156, dual = 1.2538476124, status = optimal
#   Level AB          : primal = 1.0082167929, dual = 1.0082167788, status = optimal
#   Level BB+AB       : primal = 1.0082167863, dual = 1.0082167835, status = optimal
#   Level ABB         : primal = 1.1647105953, dual = 1.1647105845, status = optimal
#   Level AAB         : primal = 1.1307194539, dual = 1.1307194459, status = optimal
#   Level AB+ABB      : primal = 1.0006793275, dual = 1.0006793146, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000026, dual = 0.9999999978, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000053, dual = 0.9999999946, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000018, dual = 0.9999999984, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000095, dual = 0.9999999920, status = optimal
#
# --- Vertex #3: (r0 = 0.440508, r1 = 0.131335) ---
#   Level 0           : primal = 1.2546861821, dual = 1.2546861682, status = optimal
#   Level AA          : primal = 1.2119703129, dual = 1.2119703056, status = optimal
#   Level BB          : primal = 1.2538476156, dual = 1.2538476124, status = optimal
#   Level AB          : primal = 1.0082167929, dual = 1.0082167788, status = optimal
#   Level BB+AB       : primal = 1.0082167863, dual = 1.0082167835, status = optimal
#   Level ABB         : primal = 1.1647105953, dual = 1.1647105845, status = optimal
#   Level AAB         : primal = 1.1307194539, dual = 1.1307194459, status = optimal
#   Level AB+ABB      : primal = 1.0006793275, dual = 1.0006793146, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000026, dual = 0.9999999978, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000051, dual = 0.9999999947, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000083, dual = 0.9999999955, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000094, dual = 0.9999999920, status = optimal
#
# --- Vertex #4: (r0 = -0.061142, r1 = 0.000000) ---
#   Level 0           : primal = 1.1975514521, dual = 1.1975514484, status = optimal
#   Level AA          : primal = 1.1540110645, dual = 1.1540110493, status = optimal
#   Level BB          : primal = 1.1975514537, dual = 1.1975514451, status = optimal
#   Level AB          : primal = 1.0032272820, dual = 1.0032272738, status = optimal
#   Level BB+AB       : primal = 1.0032272808, dual = 1.0032272752, status = optimal
#   Level ABB         : primal = 1.0449775024, dual = 1.0449774866, status = optimal
#   Level AAB         : primal = 1.0734383562, dual = 1.0734383465, status = optimal
#   Level AB+ABB      : primal = 1.0000000026, dual = 0.9999999973, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000023, dual = 0.9999999979, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000100, dual = 0.9999999917, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000013, dual = 0.9999999989, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000007, dual = 0.9999999995, status = optimal
#
# --- Vertex #5: (r0 = 0.079330, r1 = -0.309264) ---
#   Level 0           : primal = 1.2326031218, dual = 1.2326031127, status = optimal
#   Level AA          : primal = 1.2025961446, dual = 1.2025961230, status = optimal
#   Level BB          : primal = 1.2324406903, dual = 1.2324406715, status = optimal
#   Level AB          : primal = 1.0055125452, dual = 1.0055125392, status = optimal
#   Level BB+AB       : primal = 1.0055125435, dual = 1.0055125406, status = optimal
#   Level ABB         : primal = 1.1195121435, dual = 1.1195121254, status = optimal
#   Level AAB         : primal = 1.1220571181, dual = 1.1220571102, status = optimal
#   Level AB+ABB      : primal = 1.0000000070, dual = 0.9999999948, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000022, dual = 0.9999999981, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000084, dual = 0.9999999919, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000052, dual = 0.9999999948, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000078, dual = 0.9999999928, status = optimal
#
# --- Vertex #6: (r0 = 0.079330, r1 = 0.309264) ---
#   Level 0           : primal = 1.2326031218, dual = 1.2326031127, status = optimal
#   Level AA          : primal = 1.2025961446, dual = 1.2025961230, status = optimal
#   Level BB          : primal = 1.2324406903, dual = 1.2324406715, status = optimal
#   Level AB          : primal = 1.0055125452, dual = 1.0055125392, status = optimal
#   Level BB+AB       : primal = 1.0055125435, dual = 1.0055125406, status = optimal
#   Level ABB         : primal = 1.1195121435, dual = 1.1195121254, status = optimal
#   Level AAB         : primal = 1.1220571181, dual = 1.1220571102, status = optimal
#   Level AB+ABB      : primal = 1.0000000069, dual = 0.9999999948, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000021, dual = 0.9999999981, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000084, dual = 0.9999999919, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000051, dual = 0.9999999948, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000078, dual = 0.9999999928, status = optimal

# %%
theta = np.pi / 8 + 2*np.pi / (64)
tolerance = 1e-6
levels = [0, 'AA', 'BB', 'AB', 'BB+AB', 'ABB', 'AAB', 'AB+ABB', 'AA+AB+ABB', 'BB+AB+ABB', 'AA+BB+AB+ABB', 'AB+AAB+ABB']

with open("vertexCoords.json", "r") as f:
    local_vertices_data = json.load(f)

local_verts = None
for theta_value, verts in local_vertices_data:
    if abs(theta_value - theta) < tolerance:
        local_verts = np.array(verts)
        break

if local_verts is None:
    raise ValueError(f"No local polytope found for theta = {theta}")

print(f"Found {len(local_verts)} local vertices for θ = {theta:.6f}")

for i, (r0, r1) in enumerate(local_verts):
    print(f"\n--- Vertex #{i+1}: (r0 = {r0:.6f}, r1 = {r1:.6f}) ---")
    for lvl in levels:
        p, d, s = test_point_quantum_bound(theta, r0, r1, level=lvl)
        print(f"  Level {lvl:<12}: primal = {p:.10f}, dual = {d:.10f}, status = {s}")
# Out:
# Found 6 local vertices for θ = 0.490874
#
# --- Vertex #1: (r0 = 0.526058, r1 = 0.000000) ---
#   Level 0           : primal = 1.3014515282, dual = 1.3014515246, status = optimal
#   Level AA          : primal = 1.2152084395, dual = 1.2152084330, status = optimal
#   Level BB          : primal = 1.3014515306, dual = 1.3014515140, status = optimal
#   Level AB          : primal = 1.0106080574, dual = 1.0106080534, status = optimal
#   Level BB+AB       : primal = 1.0106080615, dual = 1.0106080517, status = optimal
#   Level ABB         : primal = 1.2210094966, dual = 1.2210094873, status = optimal
#   Level AAB         : primal = 1.1235866248, dual = 1.1235866227, status = optimal
#   Level AB+ABB      : primal = 1.0000000017, dual = 0.9999999983, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000008, dual = 0.9999999994, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000068, dual = 0.9999999957, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000020, dual = 0.9999999984, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000029, dual = 0.9999999965, status = optimal
#
# --- Vertex #2: (r0 = 0.508129, r1 = -0.122715) ---
#   Level 0           : primal = 1.3016984709, dual = 1.3016984690, status = optimal
#   Level AA          : primal = 1.2357679672, dual = 1.2357679620, status = optimal
#   Level BB          : primal = 1.3012152353, dual = 1.3012152158, status = optimal
#   Level AB          : primal = 1.0074161035, dual = 1.0074161000, status = optimal
#   Level BB+AB       : primal = 1.0074161038, dual = 1.0074160981, status = optimal
#   Level ABB         : primal = 1.2097959573, dual = 1.2097959463, status = optimal
#   Level AAB         : primal = 1.1559776104, dual = 1.1559776025, status = optimal
#   Level AB+ABB      : primal = 1.0005585299, dual = 1.0005585112, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000034, dual = 0.9999999975, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000014, dual = 0.9999999971, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000021, dual = 0.9999999982, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000012, dual = 0.9999999991, status = optimal
#
# --- Vertex #3: (r0 = 0.508129, r1 = 0.122715) ---
#   Level 0           : primal = 1.3016984709, dual = 1.3016984690, status = optimal
#   Level AA          : primal = 1.2357679672, dual = 1.2357679620, status = optimal
#   Level BB          : primal = 1.3012152353, dual = 1.3012152158, status = optimal
#   Level AB          : primal = 1.0074161035, dual = 1.0074161000, status = optimal
#   Level BB+AB       : primal = 1.0074161038, dual = 1.0074160981, status = optimal
#   Level ABB         : primal = 1.2097959573, dual = 1.2097959463, status = optimal
#   Level AAB         : primal = 1.1559776104, dual = 1.1559776025, status = optimal
#   Level AB+ABB      : primal = 1.0005585299, dual = 1.0005585112, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000035, dual = 0.9999999975, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000018, dual = 0.9999999982, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000024, dual = 0.9999999982, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000007, dual = 0.9999999995, status = optimal
#
# --- Vertex #4: (r0 = 0.054982, r1 = 0.000000) ---
#   Level 0           : primal = 1.2377743145, dual = 1.2377743009, status = optimal
#   Level AA          : primal = 1.1721622436, dual = 1.1721622403, status = optimal
#   Level BB          : primal = 1.2377743154, dual = 1.2377743107, status = optimal
#   Level AB          : primal = 1.0022320461, dual = 1.0022320308, status = optimal
#   Level BB+AB       : primal = 1.0022320383, dual = 1.0022320350, status = optimal
#   Level ABB         : primal = 1.0169435627, dual = 1.0169435428, status = optimal
#   Level AAB         : primal = 1.0595262517, dual = 1.0595262320, status = optimal
#   Level AB+ABB      : primal = 1.0000000025, dual = 0.9999999972, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000023, dual = 0.9999999984, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000020, dual = 0.9999999985, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000110, dual = 0.9999999915, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000011, dual = 0.9999999993, status = optimal
#
# --- Vertex #5: (r0 = 0.186038, r1 = -0.321356) ---
#   Level 0           : primal = 1.2735623351, dual = 1.2735623253, status = optimal
#   Level AA          : primal = 1.2370835477, dual = 1.2370835353, status = optimal
#   Level BB          : primal = 1.2727312549, dual = 1.2727312534, status = optimal
#   Level AB          : primal = 1.0034612039, dual = 1.0034611973, status = optimal
#   Level BB+AB       : primal = 1.0034612039, dual = 1.0034611982, status = optimal
#   Level ABB         : primal = 1.1374651817, dual = 1.1374651721, status = optimal
#   Level AAB         : primal = 1.1374651861, dual = 1.1374651670, status = optimal
#   Level AB+ABB      : primal = 1.0000000034, dual = 0.9999999975, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000037, dual = 0.9999999967, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000086, dual = 0.9999999925, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000079, dual = 0.9999999894, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000005, dual = 0.9999999996, status = optimal
#
# --- Vertex #6: (r0 = 0.186038, r1 = 0.321356) ---
#   Level 0           : primal = 1.2735623351, dual = 1.2735623253, status = optimal
#   Level AA          : primal = 1.2370835477, dual = 1.2370835353, status = optimal
#   Level BB          : primal = 1.2727312549, dual = 1.2727312534, status = optimal
#   Level AB          : primal = 1.0034612039, dual = 1.0034611973, status = optimal
#   Level BB+AB       : primal = 1.0034612039, dual = 1.0034611982, status = optimal
#   Level ABB         : primal = 1.1374651817, dual = 1.1374651721, status = optimal
#   Level AAB         : primal = 1.1374651861, dual = 1.1374651670, status = optimal
#   Level AB+ABB      : primal = 1.0000000031, dual = 0.9999999976, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000038, dual = 0.9999999967, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000087, dual = 0.9999999925, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000079, dual = 0.9999999894, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000004, dual = 0.9999999996, status = optimal

# %%
theta = np.pi / 8 + np.pi / (64)
tolerance = 1e-6
levels = [0, 'AA', 'BB', 'AB', 'BB+AB', 'ABB', 'AAB', 'AB+ABB', 'AA+AB+ABB', 'BB+AB+ABB', 'AA+BB+AB+ABB', 'AB+AAB+ABB']

with open("vertexCoords.json", "r") as f:
    local_vertices_data = json.load(f)

local_verts = None
for theta_value, verts in local_vertices_data:
    if abs(theta_value - theta) < tolerance:
        local_verts = np.array(verts)
        break

if local_verts is None:
    raise ValueError(f"No local polytope found for theta = {theta}")

print(f"Found {len(local_verts)} local vertices for θ = {theta:.6f}")

for i, (r0, r1) in enumerate(local_verts):
    print(f"\n--- Vertex #{i+1}: (r0 = {r0:.6f}, r1 = {r1:.6f}) ---")
    for lvl in levels:
        p, d, s = test_point_quantum_bound(theta, r0, r1, level=lvl)
        print(f"  Level {lvl:<12}: primal = {p:.10f}, dual = {d:.10f}, status = {s}")
# Out:
# Found 6 local vertices for θ = 0.441786
#
# --- Vertex #1: (r0 = 0.602949, r1 = 0.000000) ---
#   Level 0           : primal = 1.3542367433, dual = 1.3542367396, status = optimal
#   Level AA          : primal = 1.2339448488, dual = 1.2339448348, status = optimal
#   Level BB          : primal = 1.3542367448, dual = 1.3542367358, status = optimal
#   Level AB          : primal = 1.0069550667, dual = 1.0069550627, status = optimal
#   Level BB+AB       : primal = 1.0069550696, dual = 1.0069550627, status = optimal
#   Level ABB         : primal = 1.2914740543, dual = 1.2914740468, status = optimal
#   Level AAB         : primal = 1.1714021705, dual = 1.1714021642, status = optimal
#   Level AB+ABB      : primal = 1.0000000054, dual = 0.9999999968, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000013, dual = 0.9999999991, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000010, dual = 0.9999999993, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000021, dual = 0.9999999985, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000024, dual = 0.9999999980, status = optimal
#
# --- Vertex #2: (r0 = 0.593874, r1 = -0.115116) ---
#   Level 0           : primal = 1.3546483851, dual = 1.3546483822, status = optimal
#   Level AA          : primal = 1.2577830169, dual = 1.2577830133, status = optimal
#   Level BB          : primal = 1.3544212412, dual = 1.3544212327, status = optimal
#   Level AB          : primal = 1.0051433528, dual = 1.0051433496, status = optimal
#   Level BB+AB       : primal = 1.0051433540, dual = 1.0051433475, status = optimal
#   Level ABB         : primal = 1.2842429436, dual = 1.2842429395, status = optimal
#   Level AAB         : primal = 1.1991721265, dual = 1.1991721183, status = optimal
#   Level AB+ABB      : primal = 1.0003441203, dual = 1.0003441143, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000060, dual = 0.9999999956, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000023, dual = 0.9999999981, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000024, dual = 0.9999999982, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000012, dual = 0.9999999991, status = optimal
#
# --- Vertex #3: (r0 = 0.593874, r1 = 0.115116) ---
#   Level 0           : primal = 1.3546483851, dual = 1.3546483822, status = optimal
#   Level AA          : primal = 1.2577830169, dual = 1.2577830133, status = optimal
#   Level BB          : primal = 1.3544212412, dual = 1.3544212327, status = optimal
#   Level AB          : primal = 1.0051433528, dual = 1.0051433496, status = optimal
#   Level BB+AB       : primal = 1.0051433540, dual = 1.0051433475, status = optimal
#   Level ABB         : primal = 1.2842429436, dual = 1.2842429395, status = optimal
#   Level AAB         : primal = 1.1991721265, dual = 1.1991721183, status = optimal
#   Level AB+ABB      : primal = 1.0003441203, dual = 1.0003441143, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000061, dual = 0.9999999956, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000131, dual = 0.9999999937, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000023, dual = 0.9999999982, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000013, dual = 0.9999999991, status = optimal
#
# --- Vertex #4: (r0 = 0.259286, r1 = 0.000000) ---
#   Level 0           : primal = 1.2974672039, dual = 1.2974671974, status = optimal
#   Level AA          : primal = 1.1976630743, dual = 1.1976630697, status = optimal
#   Level BB          : primal = 1.2974672124, dual = 1.2974671901, status = optimal
#   Level AB          : primal = 1.0012340329, dual = 1.0012340237, status = optimal
#   Level BB+AB       : primal = 1.0012340278, dual = 1.0012340262, status = optimal
#   Level ABB         : primal = 1.0495131100, dual = 1.0495131001, status = optimal
#   Level AAB         : primal = 1.0767621947, dual = 1.0767621793, status = optimal
#   Level AB+ABB      : primal = 1.0000000068, dual = 0.9999999950, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000043, dual = 0.9999999955, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000014, dual = 0.9999999995, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000010, dual = 0.9999999994, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000009, dual = 0.9999999993, status = optimal
#
# --- Vertex #5: (r0 = 0.363104, r1 = -0.349725) ---
#   Level 0           : primal = 1.3324036583, dual = 1.3324036555, status = optimal
#   Level AA          : primal = 1.2820299195, dual = 1.2820299170, status = optimal
#   Level BB          : primal = 1.3312819168, dual = 1.3312819083, status = optimal
#   Level AB          : primal = 1.0018261505, dual = 1.0018261457, status = optimal
#   Level BB+AB       : primal = 1.0018261562, dual = 1.0018261415, status = optimal
#   Level ABB         : primal = 1.1832513689, dual = 1.1832513585, status = optimal
#   Level AAB         : primal = 1.1832872015, dual = 1.1832871930, status = optimal
#   Level AB+ABB      : primal = 1.0000000037, dual = 0.9999999967, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000049, dual = 0.9999999940, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000028, dual = 0.9999999978, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000025, dual = 0.9999999975, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000020, dual = 0.9999999981, status = optimal
#
# --- Vertex #6: (r0 = 0.363104, r1 = 0.349725) ---
#   Level 0           : primal = 1.3324036583, dual = 1.3324036555, status = optimal
#   Level AA          : primal = 1.2820299196, dual = 1.2820299170, status = optimal
#   Level BB          : primal = 1.3312819168, dual = 1.3312819083, status = optimal
#   Level AB          : primal = 1.0018261501, dual = 1.0018261457, status = optimal
#   Level BB+AB       : primal = 1.0018261562, dual = 1.0018261415, status = optimal
#   Level ABB         : primal = 1.1832513689, dual = 1.1832513585, status = optimal
#   Level AAB         : primal = 1.1832872015, dual = 1.1832871930, status = optimal
#   Level AB+ABB      : primal = 1.0000000037, dual = 0.9999999967, status = optimal
#   Level AA+AB+ABB   : primal = 1.0000000050, dual = 0.9999999939, status = optimal
#   Level BB+AB+ABB   : primal = 1.0000000028, dual = 0.9999999978, status = optimal
#   Level AA+BB+AB+ABB: primal = 1.0000000022, dual = 0.9999999976, status = optimal
#   Level AB+AAB+ABB  : primal = 1.0000000020, dual = 0.9999999982, status = optimal

# %% [markdown]
# ## Extracting the certificate at $T_{1+A+B+AB+ABB}$

# %% [markdown]
# We are able to reach $\beta_T$ at this level of the hierarchy.

# %%
def get_extra_monomials():
    """
    Returns additional monomials to add to sdp relaxation.
    """

    monos = []

    Aflat = ncp.flatten(A)
    Bflat = ncp.flatten(B)
    
    # AB
    for a in Aflat:
        for b in Bflat:
            monos += [a*b]

    # ABB
    for a in Aflat:
        for b in Bflat:
            for b2 in Bflat:
                monos += [a*b*b2]
    
    return monos[:]

moment_ineqs = []                      # moment inequalities
moment_eqs = []                        # moment equalities
op_eqs = []                            # operator equalities
op_ineqs = []                          # operator inequalities
extra_monos = get_extra_monomials()   # extra monomials

Theta = np.pi/4
r0 = 1 - 1/np.sqrt(2) # p1 = r0
r1 = 0 # p4 = 1/2 r1
s = np.sqrt(2)
sin_2T = np.sin(2 * Theta)
sin_4T = np.sin(4 * Theta)
cos_2T = np.cos(2 * Theta)
cos_4T = np.cos(4 * Theta)
cos_6T = np.cos(6 * Theta)

obj = (-1/(2*(3 - cos_4T))*0.5*r1*(-4*B[1][0]*(-3 + cos_4T) + s*(-5*cos_2T + cos_6T)*A[0][0]*B[1][0] 
    + s*(-5*cos_2T + cos_6T)*A[1][0]*B[1][0] + 2*s*A[0][0]*(-3 + cos_4T)*sin_2T - 2*s*A[1][0]*(-3 + cos_4T)*sin_2T) 
    - 1/(2*(3 - cos_4T))*(-4*B[0][0]*cos_2T - s*A[0][0]*B[0][0] + s*cos_4T*A[0][0]*B[0][0] - s*A[1][0]*B[0][0] 
    + s*cos_4T*A[1][0]*B[0][0] - 2*s*A[0][0]*B[1][0]*sin_2T + 2*s*A[1][0]*B[1][0]*sin_2T) 
    - 1/(2*(3 - cos_4T))*r0*(s*A[0][0]*(-3 + cos_4T) + s*A[1][0]*(-3 + cos_4T) - 4*B[0][0]*(-1 + cos_4T) 
    + 2*s*cos_2T*A[0][0]*B[0][0] + 2*s*cos_2T*A[1][0]*B[0][0] - 2*s*cos_2T*A[0][0]*B[1][0]*sin_2T + s*A[1][0]*B[1][0]*sin_4T))


sdp = ncp.SdpRelaxation(ops, verbose=0, normalized=True, parallel=0)
sdp.get_relaxation(
    level=0,
    equalities = op_eqs[:],
    inequalities = op_ineqs[:],
    momentequalities = moment_eqs[:],
    momentinequalities = moment_ineqs[:],
    objective=-obj,
    substitutions = subs,
    extramonomials = extra_monos
)
sdp.solve(solver="mosek")
print(-sdp.primal, -sdp.dual, sdp.status)
# Out:
# 1.0000000083684621 0.9999999939884063 optimal

# %%
b = sdp.y_mat[0]
print(b)
np.savetxt("Gamma.csv", b, delimiter=",")
# Out:
# [[ 2.01690141e-01 -4.70151340e-02 -4.70151298e-02  7.32242705e-02
#    1.76690225e-11 -8.23302327e-02 -6.02862953e-02 -8.23302286e-02
#    6.02862913e-02 -4.07424750e-04  4.35463592e-03  4.07424712e-04
#   -4.35463183e-03]
#  [-4.70151340e-02  8.97906600e-02  8.84037876e-03 -7.81067059e-02
#   -5.43191544e-02  4.18571766e-02  1.80198513e-02  1.52269678e-02
#    8.61489393e-03  1.30811715e-02  5.10049391e-03 -1.30811660e-02
#   -9.23367549e-03]
#  [-4.70151298e-02  8.84037876e-03  8.97906641e-02 -7.81067058e-02
#    5.43191585e-02  1.52269649e-02 -8.61489395e-03  4.18571737e-02
#   -1.80198513e-02  1.30811660e-02  9.23367675e-03 -1.30811715e-02
#   -5.10049690e-03]
#  [ 7.32242705e-02 -7.81067059e-02 -7.81067058e-02  1.98380116e-01
#    8.49680391e-11 -5.21813296e-02  4.05731654e-04 -5.21813297e-02
#   -4.05731572e-04 -6.21712454e-02  4.00484575e-14  6.21712453e-02
#    9.17409352e-13]
#  [ 1.76690225e-11 -5.43191544e-02  5.43191585e-02  8.49680391e-11
#    9.99295307e-02 -4.35294283e-03 -4.35692686e-03  4.35293869e-03
#   -4.35693096e-03  1.00238462e-13 -1.63397565e-02 -5.19926927e-13
#   -1.63397607e-02]
#  [-8.23302327e-02  4.18571766e-02  1.52269649e-02 -5.21813296e-02
#   -4.35294283e-03  6.20639073e-02  1.84308649e-02  3.97861030e-02
#    3.84748926e-03  2.86897490e-04 -1.83068152e-02 -2.86894001e-04
#   -2.16725782e-03]
#  [-6.02862953e-02  1.80198513e-02 -8.61489395e-03  4.05731654e-04
#   -4.35692686e-03  1.84308649e-02  4.64762295e-02 -3.84749046e-03
#   -2.41973216e-02 -9.34166564e-12 -5.24600722e-03  3.09017759e-11
#   -1.52269678e-02]
#  [-8.23302286e-02  1.52269678e-02  4.18571737e-02 -5.21813297e-02
#    4.35293869e-03  3.97861030e-02 -3.84749046e-03  6.20639057e-02
#   -1.84308620e-02  2.86894021e-04  2.16725782e-03 -2.86897500e-04
#    1.83068152e-02]
#  [ 6.02862913e-02  8.61489393e-03 -1.80198513e-02 -4.05731572e-04
#   -4.35693096e-03  3.84748926e-03 -2.41973216e-02 -1.84308620e-02
#    4.64762254e-02 -3.12048763e-11 -1.52269649e-02  9.88700578e-12
#   -5.24600433e-03]
#  [-4.07424750e-04  1.30811715e-02  1.30811660e-02 -6.21712454e-02
#    1.00238462e-13  2.86897490e-04 -9.34166564e-12  2.86894021e-04
#   -3.12048763e-11  3.08813496e-02 -1.21000920e-11 -3.08813433e-02
#    3.25326494e-14]
#  [ 4.35463592e-03  5.10049391e-03  9.23367675e-03  4.00484575e-14
#   -1.63397565e-02 -1.83068152e-02 -5.24600722e-03  2.16725782e-03
#   -1.52269649e-02 -1.21000920e-11  2.07879639e-02 -9.90205923e-15
#    6.45218311e-03]
#  [ 4.07424712e-04 -1.30811660e-02 -1.30811715e-02  6.21712453e-02
#   -5.19926927e-13 -2.86894001e-04  3.09017759e-11 -2.86897500e-04
#    9.88700578e-12 -3.08813433e-02 -9.90205923e-15  3.08813495e-02
#    1.21586788e-11]
#  [-4.35463183e-03 -9.23367549e-03 -5.10049690e-03  9.17409352e-13
#   -1.63397607e-02 -2.16725782e-03 -1.52269678e-02  1.83068152e-02
#   -5.24600433e-03  3.25326494e-14  6.45218311e-03  1.21586788e-11
#    2.07879656e-02]]

# %% [markdown]
# ## Victor's Bell expression, $T_{1+A+B+AB+ABB'}$

# %%
def get_extra_monomials():
    """
    Returns additional monomials to add to sdp relaxation.
    """

    monos = []

    Aflat = ncp.flatten(A)
    Bflat = ncp.flatten(B)

    #AB
    for a in Aflat:
        for b in Bflat:
            monos += [a*b]

    # ABB
    for a in Aflat:
        for b in Bflat:
            for b2 in Bflat:
                monos += [a*b*b2]
    
    return monos[:]

moment_ineqs = []                      # moment inequalities
moment_eqs = []                        # moment equalities
op_eqs = []                            # operator equalities
op_ineqs = []                          # operator inequalities
extra_monos = get_extra_monomials()    # extra monomials

# Compute quantum value of Bell expression at (p1, p4) for a given Theta
r0 = 1 - 1/np.sqrt(2)
r1 = 0

# Victor's Bell expression
obj = r0*((A[0][0] + A[1][0])/np.sqrt(2) - B[0][0]) + r1*((A[0][0] - A[1][0])/np.sqrt(2) - B[1][0]) + 1/(2*np.sqrt(2))*(A[0][0]*B[0][0] + A[1][0]*B[0][0] + A[0][0]*B[1][0] - A[1][0]*B[1][0])

sdp = ncp.SdpRelaxation(ops, verbose=0, normalized=True, parallel=0)
sdp.get_relaxation(
    level=0,
    equalities = op_eqs[:],
    inequalities = op_ineqs[:],
    momentequalities = moment_eqs[:],
    momentinequalities = moment_ineqs[:],
    objective=-obj,
    substitutions = subs,
    extramonomials = extra_monos
)
sdp.solve(solver="mosek")
print(-sdp.primal, -sdp.dual, sdp.status)
sosvictor = sdp.get_sos_decomposition()
# Out:
# 1.00000000835675 0.9999999939876847 optimal

# %% [markdown]
# We want to extract the dual solution in the monomial basis:

# %%
Gamma = sdp.x_mat[0]
Wmon = sdp.y_mat[0]
print(Wmon)

np.savetxt("Wmon.csv", Wmon, delimiter=",")
np.savetxt("Gamma.csv", Gamma, delimiter=",")
# Out:
# [[ 2.01690088e-01 -4.70151546e-02 -4.70150952e-02  7.32242701e-02
#    2.33116392e-10 -8.23302791e-02 -6.02862652e-02 -8.23302206e-02
#    6.02862070e-02 -4.07413137e-04  4.35468180e-03  4.07412623e-04
#   -4.35462303e-03]
#  [-4.70151546e-02  8.97906867e-02  8.84035154e-03 -7.81066671e-02
#   -5.43192393e-02  4.18571525e-02  1.80198594e-02  1.52269742e-02
#    8.61485540e-03  1.30811542e-02  5.10053686e-03 -1.30811489e-02
#   -9.23365298e-03]
#  [-4.70150952e-02  8.84035154e-03  8.97907460e-02 -7.81066650e-02
#    5.43192984e-02  1.52269320e-02 -8.61485567e-03  4.18571107e-02
#   -1.80198596e-02  1.30811481e-02  9.23367103e-03 -1.30811538e-02
#   -5.10057960e-03]
#  [ 7.32242701e-02 -7.81066671e-02 -7.81066650e-02  1.98379981e-01
#    1.07251209e-09 -5.21813173e-02  4.05720622e-04 -5.21813178e-02
#   -4.05719524e-04 -6.21711906e-02  1.14861721e-12  6.21711897e-02
#    7.48866333e-13]
#  [ 2.33116392e-10 -5.43192393e-02  5.43192984e-02  1.07251209e-09
#    9.99297193e-02 -4.35298928e-03 -4.35691852e-03  4.35292993e-03
#   -4.35697745e-03  2.58821921e-13 -1.63397490e-02  6.41535243e-15
#   -1.63398094e-02]
#  [-8.23302791e-02  4.18571525e-02  1.52269320e-02 -5.21813173e-02
#   -4.35298928e-03  6.20639289e-02  1.84308381e-02  3.97861625e-02
#    3.84747787e-03  2.86888929e-04 -1.83068152e-02 -2.86885362e-04
#   -2.16720105e-03]
#  [-6.02862652e-02  1.80198594e-02 -8.61485567e-03  4.05720622e-04
#   -4.35691852e-03  1.84308381e-02  4.64762126e-02 -3.84749514e-03
#   -2.41973271e-02 -1.21130892e-10 -5.24598280e-03  4.01712174e-10
#   -1.52269739e-02]
#  [-8.23302206e-02  1.52269742e-02  4.18571107e-02 -5.21813178e-02
#    4.35292993e-03  3.97861625e-02 -3.84749514e-03  6.20639048e-02
#   -1.84307968e-02  2.86885628e-04  2.16720105e-03 -2.86889031e-04
#    1.83068152e-02]
#  [ 6.02862070e-02  8.61485540e-03 -1.80198596e-02 -4.05719524e-04
#   -4.35697745e-03  3.84747787e-03 -2.41973271e-02 -1.84307968e-02
#    4.64761544e-02 -4.01745914e-10 -1.52269323e-02  1.20766480e-10
#   -5.24594133e-03]
#  [-4.07413137e-04  1.30811542e-02  1.30811481e-02 -6.21711906e-02
#    2.58821921e-13  2.86888929e-04 -1.21130892e-10  2.86885628e-04
#   -4.01745914e-10  3.08813287e-02 -1.77289177e-10 -3.08813218e-02
#   -7.12071061e-14]
#  [ 4.35468180e-03  5.10053686e-03  9.23367103e-03  1.14861721e-12
#   -1.63397490e-02 -1.83068152e-02 -5.24598280e-03  2.16720105e-03
#   -1.52269323e-02 -1.77289177e-10  2.07879528e-02  5.56906222e-14
#    6.45213481e-03]
#  [ 4.07412623e-04 -1.30811489e-02 -1.30811538e-02  6.21711897e-02
#    6.41535243e-15 -2.86885362e-04  4.01712174e-10 -2.86889031e-04
#    1.20766480e-10 -3.08813218e-02  5.56906222e-14  3.08813274e-02
#    1.77037288e-10]
#  [-4.35462303e-03 -9.23365298e-03 -5.10057960e-03  7.48866333e-13
#   -1.63398094e-02 -2.16720105e-03 -1.52269739e-02  1.83068152e-02
#   -5.24594133e-03 -7.12071061e-14  6.45213481e-03  1.77037288e-10
#    2.07879778e-02]]

# %% [markdown]
# ## Victor's Bell expression reverted, $T_{1+A+B+AB+ABB}$

# %%
def get_extra_monomials():
    """
    Returns additional monomials to add to sdp relaxation.
    """

    monos = []

    Aflat = ncp.flatten(A)
    Bflat = ncp.flatten(B)

    #AB
    for a in Aflat:
        for b in Bflat:
            monos += [a*b]

    # ABB
    for a in Aflat:
        for b in Bflat:
            for b2 in Bflat:
                monos += [a*b*b2]
    
    return monos[:]

moment_ineqs = []                      # moment inequalities
moment_eqs = []                        # moment equalities
op_eqs = []                            # operator equalities
op_ineqs = []                          # operator inequalities
extra_monos = get_extra_monomials()    # extra monomials

# Compute quantum value of Bell expression at (p1, p4) for a given Theta
r0 = 1 - 1/np.sqrt(2)
r1 = 0

# Victor's Bell expression
obj = r0*((B[0][0] + B[1][0])/np.sqrt(2) - A[0][0]) + r1*((B[0][0] - B[1][0])/np.sqrt(2) - A[1][0]) + 1/(2*np.sqrt(2))*(A[0][0]*B[0][0] + A[1][0]*B[0][0] + A[0][0]*B[1][0] - A[1][0]*B[1][0])

sdp = ncp.SdpRelaxation(ops, verbose=0, normalized=True, parallel=0)
sdp.get_relaxation(
    level=0,
    equalities = op_eqs[:],
    inequalities = op_ineqs[:],
    momentequalities = moment_eqs[:],
    momentinequalities = moment_ineqs[:],
    objective=-obj,
    substitutions = subs,
    extramonomials = extra_monos
)
sdp.solve(solver="mosek")
print(-sdp.primal, -sdp.dual, sdp.status)
sosvictor = sdp.get_sos_decomposition()
# Out:
# 1.000891103574409 1.0008910972216816 optimal
